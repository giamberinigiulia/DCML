# %% [markdown]
# <a href="https://colab.research.google.com/github/giamberinigiulia/DCML/blob/main/project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: mount content/Drive

from google.colab import drive
drive.mount('/content/Drive')
# Out:
# Drive already mounted at /content/Drive; to attempt to forcibly remount, call drive.mount("/content/Drive", force_remount=True).

# %%
# prompt: parse a file inserting in a list the element of the file that are in between <CODESPLIT>

from google.colab import drive
drive.mount('/content/Drive')

def parse_file(filepath):
  with open(filepath, 'r') as file:
    content = file.read()
    # Split the content by <CODESPLIT>
    parts = content.split('<CODESPLIT>')

      # Remove the first element if it's empty (text before the first <CODESPLIT>)
    if parts[0] == '':
        parts.pop(0)

    # Filter out parts containing links
    filtered_parts = [part for part in parts if 'http://' not in part and 'https://' not in part]

    return filtered_parts
# Out:
# Drive already mounted at /content/Drive; to attempt to forcibly remount, call drive.mount("/content/Drive", force_remount=True).

# %%
def parse_content(parts):
    parsed_data = []
    for i in range(len(parts)):
        if 'def ' in parts[i]:
            snippet_of_code = parts[i].strip()
            description = parts[i-1].strip() if i > 0 else "No description available"
            name_of_function = parts[i-2].strip() if i > 1 else "Unknown Function"

            parsed_data.append({
                "name of the function": name_of_function,
                "description": description,
                "snippet of code": snippet_of_code
            })

    return parsed_data

# %%
import pandas as pd

# Example usage (assuming the file is in /content/Drive/My Drive/my_file.txt):
filepath = "/content/Drive/My Drive/MLSA/CodeSearch/train.txt"  # Replace with actual file path
extracted_code = parse_file(filepath)
parsed_data = parse_content(extracted_code)
df = pd.DataFrame(parsed_data)

# %%
df.head(20)
# Out:
#                 name of the function  \
# 0       InteractiveDecorator._logdef
# 1               Writer._write_frames
# 2   WinkApiInterface.update_firmware
# 3                             select
# 4                 Optimizer._rmsprop
# 5               ArcLine.linspace_pix
# 6          BuildClient.save_template
# 7       ScalableBloomFilter.fromfile
# 8                    SamTemplate.get
# 9     _resolve_items_to_service_uids
# 10             MarWriter.add_fileobj
# 11                        masked_max
# 12             Highmap.add_CSSsource
# 13                     GSheet._login
# 14            ProcessingBlock.get_id
# 15    ServerCommon.common_update_sys
# 16                     format_supsub
# 17                   OqParam.min_iml
# 18                    Recipe.filters
# 19              SGD.make_association
#
#                                           description  \
# 0   Logs the definition of the object that was jus...
# 1                   Write metadata to a file handle .
# 2   Make a call to the update_firmware endpoint . ...
# 3                                     datbase dialect
# 4       Uses RMSProp to compute step from gradients .
# 5   Return x y values evaluated with a given pixel...
# 6   SaveTemplate . Updates an existing build defin...
# 7   Serialize this ScalableBloomFilter into the fi...
# 8   Gets the resource at the given logicalId if pr...
# 9   This function returns a list of UIDs from anal...
# 10  Add the contents of a file object to the MAR f...
# 11  To calculate mean along certain dimensions on ...
# 12             set data for series option in highmaps
# 13                           Makes imports : return :
# 14   Generate a Processing Block ( PB ) Instance ID .
# 15  If a record matching the instance already exis...
# 16  Mainly used for Analysis Service s unit . Tran...
# 17  : returns : a numpy array of intensities one p...
# 18  Add a list of Filter ingredients to the query ...
# 19  contstruct the association : param record : : ...
#
#                                       snippet of code
# 0   def _logdef ( self , n , o , otype ) : import ...
# 1   def _write_frames ( self , handle ) : assert h...
# 2   def update_firmware ( self , device , id_overr...
# 3   def select ( table , key = 'default' ) : datab...
# 4   def _rmsprop ( self , grads , cache = None , d...
# 5   def linspace_pix ( self , start = None , stop ...
# 6   def save_template ( self , template , project ...
# 7   def fromfile ( cls , f ) : filter = cls ( ) fi...
# 8   def get ( self , logicalId ) : if logicalId no...
# 9   def _resolve_items_to_service_uids ( items ) :...
# 10  def add_fileobj ( self , fileobj , path , comp...
# 11  def masked_max ( vector : torch . Tensor , mas...
# 12  def add_CSSsource ( self , new_src ) : if isin...
# 13  def _login ( self ) : # TODO(dmvieira) login c...
# 14  def get_id ( date : datetime . datetime ) -> s...
# 15  def common_update_sys ( self ) : try : sudo ( ...
# 16  def format_supsub ( text ) : out = [ ] subsup ...
# 17  def min_iml ( self ) : mini = self . minimum_i...
# 18  def filters ( self , * filters ) : def filter_...
# 19  def make_association ( self , record ) : # pre...

# %%
import re
def custom_tokenizer(code):
    # Define regex patterns for different token types
    token_specification = [
        ('NUMBER',    r'\b\d+(\.\d*)?\b'),  # Integer or decimal number
        ('ASSIGN',    r'='),                # Assignment operator
        ('END',       r';'),                # Statement terminator
        ('ID',        r'\b[A-Za-z_]\w*\b'), # Identifiers
        ('OP',        r'[+\-*/]'),          # Arithmetic operators
        ('NEWLINE',   r'\n'),               # Line endings
        ('PAREN',     r'[({}\[\])]'),       # Parentheses
        ('SKIP',      r'[ \t]+'),           # Skip over spaces and tabs
        ('MISMATCH',  r'.'),                # Any other character
    ]
    tok_regex = '|'.join('(?P<%s>%s)' % pair for pair in token_specification)
    get_token = re.compile(tok_regex).finditer
    tokens = []
    for match in get_token(code):
        kind = match.lastgroup
        value = match.group()
        if kind == 'ID' and value in {'def', 'return', 'if', 'else', 'for', 'while'}:
            kind = 'KEYWORD'
        elif kind == 'SKIP':
            continue
        elif kind == 'MISMATCH':
            continue  # Ignore mismatched characters instead of raising an error
        tokens.append((kind, value))
    return tokens

# %%
# !pip install nltk
import nltk
nltk.download('punkt_tab')

from nltk.tokenize import word_tokenize

# length of df
df.describe()
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.6)
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
#        name of the function          description  \
# count                810928               810928
# unique               362847               377493
# top                    main  Auto Generated Code
# freq                   3053                 3251
#
#                                          snippet of code
# count                                             810928
# unique                                            557399
# top     Dump the function def of a macro or call block .
# freq                                                   6

# %%
print(df['snippet of code'].iloc[0])
# Out:
# def _logdef ( self , n , o , otype ) : import re try : #The latest input cell will be the one that this got executed #from. TODO: actually, if acorn got imported after the fact, then #the import would have caused all the undecorated functions to be #decorated as soon as acorn imported. I suppose we just won't have #any code for that case. if otype == "classes" : cellno = max ( [ int ( k [ 2 : ] ) for k in self . shell . user_ns . keys ( ) if re . match ( "_i\d+" , k ) ] ) elif otype == "functions" : cellno = int ( o . __code__ . co_filename . strip ( "<>" ) . split ( '-' ) [ 2 ] ) except : #This must not have been an ipython notebook declaration, so we #don't store the code. cellno = None pass code = "" if cellno is not None : cellstr = "_i{0:d}" . format ( cellno ) if cellstr in self . shell . user_ns : cellcode = self . shell . user_ns [ cellstr ] import ast astm = ast . parse ( cellcode ) ab = astm . body parts = { ab [ i ] . name : ( ab [ i ] . lineno , None if i + 1 >= len ( ab ) else ab [ i + 1 ] . lineno ) for i , d in enumerate ( ab ) } if n in parts : celllines = cellcode . split ( '\n' ) start , end = parts [ n ] if end is not None : code = celllines [ start - 1 : end - 1 ] else : code = celllines [ start - 1 : ] #Now, we actually create the entry. Since the execution for function #definitions is almost instantaneous, we just log the pre and post #events at the same time. from time import time from acorn . logging . database import record entry = { "m" : "def" , "a" : None , "s" : time ( ) , "r" : None , "c" : code , } from acorn import msg record ( "__main__.{}" . format ( n ) , entry , diff = True ) msg . info ( entry , 1 )
# 0

# %%
# Tokenize only the first element of df["snippet of code"]
first_snippet_tokenized = custom_tokenizer(df['snippet of code'].iloc[0])

# Print the tokenized first snippet of code
print(first_snippet_tokenized)
# Out:
# [('KEYWORD', 'def'), ('ID', '_logdef'), ('PAREN', '('), ('ID', 'self'), ('ID', 'n'), ('ID', 'o'), ('ID', 'otype'), ('PAREN', ')'), ('ID', 'import'), ('ID', 're'), ('ID', 'try'), ('ID', 'The'), ('ID', 'latest'), ('ID', 'input'), ('ID', 'cell'), ('ID', 'will'), ('ID', 'be'), ('ID', 'the'), ('ID', 'one'), ('ID', 'that'), ('ID', 'this'), ('ID', 'got'), ('ID', 'executed'), ('ID', 'from'), ('ID', 'TODO'), ('ID', 'actually'), ('KEYWORD', 'if'), ('ID', 'acorn'), ('ID', 'got'), ('ID', 'imported'), ('ID', 'after'), ('ID', 'the'), ('ID', 'fact'), ('ID', 'then'), ('ID', 'the'), ('ID', 'import'), ('ID', 'would'), ('ID', 'have'), ('ID', 'caused'), ('ID', 'all'), ('ID', 'the'), ('ID', 'undecorated'), ('ID', 'functions'), ('ID', 'to'), ('ID', 'be'), ('ID', 'decorated'), ('ID', 'as'), ('ID', 'soon'), ('ID', 'as'), ('ID', 'acorn'), ('ID', 'imported'), ('ID', 'I'), ('ID', 'suppose'), ('ID', 'we'), ('ID', 'just'), ('ID', 'won'), ('ID', 't'), ('ID', 'have'), ('ID', 'any'), ('ID', 'code'), ('KEYWORD', 'for'), ('ID', 'that'), ('ID', 'case'), ('KEYWORD', 'if'), ('ID', 'otype'), ('ASSIGN', '='), ('ASSIGN', '='), ('ID', 'classes'), ('ID', 'cellno'), ('ASSIGN', '='), ('ID', 'max'), ('PAREN', '('), ('PAREN', '['), ('ID', 'int'), ('PAREN', '('), ('ID', 'k'), ('PAREN', '['), ('NUMBER', '2'), ('PAREN', ']'), ('PAREN', ')'), ('KEYWORD', 'for'), ('ID', 'k'), ('ID', 'in'), ('ID', 'self'), ('ID', 'shell'), ('ID', 'user_ns'), ('ID', 'keys'), ('PAREN', '('), ('PAREN', ')'), ('KEYWORD', 'if'), ('ID', 're'), ('ID', 'match'), ('PAREN', '('), ('ID', '_i'), ('ID', 'd'), ('OP', '+'), ('ID', 'k'), ('PAREN', ')'), ('PAREN', ']'), ('PAREN', ')'), ('ID', 'elif'), ('ID', 'otype'), ('ASSIGN', '='), ('ASSIGN', '='), ('ID', 'functions'), ('ID', 'cellno'), ('ASSIGN', '='), ('ID', 'int'), ('PAREN', '('), ('ID', 'o'), ('ID', '__code__'), ('ID', 'co_filename'), ('ID', 'strip'), ('PAREN', '('), ('PAREN', ')'), ('ID', 'split'), ('PAREN', '('), ('OP', '-'), ('PAREN', ')'), ('PAREN', '['), ('NUMBER', '2'), ('PAREN', ']'), ('PAREN', ')'), ('ID', 'except'), ('ID', 'This'), ('ID', 'must'), ('ID', 'not'), ('ID', 'have'), ('ID', 'been'), ('ID', 'an'), ('ID', 'ipython'), ('ID', 'notebook'), ('ID', 'declaration'), ('ID', 'so'), ('ID', 'we'), ('ID', 'don'), ('ID', 't'), ('ID', 'store'), ('ID', 'the'), ('ID', 'code'), ('ID', 'cellno'), ('ASSIGN', '='), ('ID', 'None'), ('ID', 'pass'), ('ID', 'code'), ('ASSIGN', '='), ('KEYWORD', 'if'), ('ID', 'cellno'), ('ID', 'is'), ('ID', 'not'), ('ID', 'None'), ('ID', 'cellstr'), ('ASSIGN', '='), ('ID', '_i'), ('PAREN', '{'), ('NUMBER', '0'), ('ID', 'd'), ('PAREN', '}'), ('ID', 'format'), ('PAREN', '('), ('ID', 'cellno'), ('PAREN', ')'), ('KEYWORD', 'if'), ('ID', 'cellstr'), ('ID', 'in'), ('ID', 'self'), ('ID', 'shell'), ('ID', 'user_ns'), ('ID', 'cellcode'), ('ASSIGN', '='), ('ID', 'self'), ('ID', 'shell'), ('ID', 'user_ns'), ('PAREN', '['), ('ID', 'cellstr'), ('PAREN', ']'), ('ID', 'import'), ('ID', 'ast'), ('ID', 'astm'), ('ASSIGN', '='), ('ID', 'ast'), ('ID', 'parse'), ('PAREN', '('), ('ID', 'cellcode'), ('PAREN', ')'), ('ID', 'ab'), ('ASSIGN', '='), ('ID', 'astm'), ('ID', 'body'), ('ID', 'parts'), ('ASSIGN', '='), ('PAREN', '{'), ('ID', 'ab'), ('PAREN', '['), ('ID', 'i'), ('PAREN', ']'), ('ID', 'name'), ('PAREN', '('), ('ID', 'ab'), ('PAREN', '['), ('ID', 'i'), ('PAREN', ']'), ('ID', 'lineno'), ('ID', 'None'), ('KEYWORD', 'if'), ('ID', 'i'), ('OP', '+'), ('NUMBER', '1'), ('ASSIGN', '='), ('ID', 'len'), ('PAREN', '('), ('ID', 'ab'), ('PAREN', ')'), ('KEYWORD', 'else'), ('ID', 'ab'), ('PAREN', '['), ('ID', 'i'), ('OP', '+'), ('NUMBER', '1'), ('PAREN', ']'), ('ID', 'lineno'), ('PAREN', ')'), ('KEYWORD', 'for'), ('ID', 'i'), ('ID', 'd'), ('ID', 'in'), ('ID', 'enumerate'), ('PAREN', '('), ('ID', 'ab'), ('PAREN', ')'), ('PAREN', '}'), ('KEYWORD', 'if'), ('ID', 'n'), ('ID', 'in'), ('ID', 'parts'), ('ID', 'celllines'), ('ASSIGN', '='), ('ID', 'cellcode'), ('ID', 'split'), ('PAREN', '('), ('ID', 'n'), ('PAREN', ')'), ('ID', 'start'), ('ID', 'end'), ('ASSIGN', '= ...

# %%
def process_in_chunks(df, chunk_size=100):
    """
    Processes the DataFrame in consecutive chunks, applying custom_tokenizer.

    Args:
        df: The pandas DataFrame to process.
        chunk_size: The number of rows to process in each chunk.

    Returns:
        The DataFrame with the 'tokenized_snippet' column added.
    """
    df['tokenized_snippet'] = ''  # Initialize the column
    num_chunks = (len(df) + chunk_size - 1) // chunk_size  # Calculate the number of chunks

    for i in range(num_chunks):
        start_index = i * chunk_size
        end_index = min((i + 1) * chunk_size, len(df))  # Ensure we don't go beyond the DataFrame bounds
        chunk = df['snippet of code'].iloc[start_index:end_index]
        df['tokenized_snippet'].iloc[start_index:end_index] = chunk.apply(custom_tokenizer)

    return df

# %%
df_tokenized = process_in_chunks(df, chunk_size=100)
df_tokenized.head()
# Out:
# Output streaming troncato alle ultime 5000 righe.
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['tokenized_snippet'].iloc[start_index:end_index] = chunk.apply(custom_tokenizer)
# <ipython-input-10-36c0434d3d06>:19: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['tokenized_snippet'].iloc[start_index:end_index] = chunk.apply(custom_tokenizer)
# <ipython-input-10-36c0434d3d06>:19: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['tokenized_snippet'].iloc[start_index:end_index] = chunk.apply(custom_tokenizer)
# <ipython-input-10-36c0434d3d06>:19: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['tokenized_snippet'].iloc[start_index:end_index] = chunk.apply(custom_tokenizer)
# <ipython-input-10-36c0434d3d06>:19: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['tokenized_snippet'].iloc[start_index:end_index] = chunk.apply(custom_tokenizer)
# <ipython-input-10-36c0434d3d06>:19: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['tokenized_snippet'].iloc[start_index:end_index] = chunk.apply(custom_tokenizer)
# <ipython-input-10-36c0434d3d06>:19: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['tokenized_snippet'].iloc[start_index:end_index] = chunk.apply(custom_tokenizer)
# <ipython-input-10-36c0434d3d06>:19: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['tokenized_snippet'].iloc[start_index:end_index] = chunk.apply(custom_tokenizer)
# <ipython-input-10-36c0434d3d06>:19: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['tokenized_snippet'].iloc[start_index:end_index] = chunk.apply(custom_tokenizer)
# <ipython-input-10-36c0434d3d06>:19: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['tokenized_snippet'].iloc[start_index:end_index] = chunk.apply(custom_tokenizer)
# <ipython-input-10-36c0434d3d06>:19: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['tokenized_snippet'].iloc[start_index:end_index] = chunk.apply(custom_tokenizer)
# <ipython-input-10-36c0434d3d06>:19: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['tokenized_snippet'].iloc[start_index:end_index] = chunk.apply(custom_tokenizer)
# <ipython-input-10-36c0434d3d06>:19: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['tokenized_snippet'].iloc[start_index:end_index] = chunk.apply(custom_tokenizer)
# <ipython-input-10-36c0434d3d06>:19: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['tokenized_snippet'].iloc[start_index:end_index] = chunk.apply(custom_tokenizer)
# <ipython-input-10-36c0434d3d06>:19: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['tokenized_snippet'].iloc[start_index:end_index] = chunk.apply(custom_tokenizer)
# <ipython-input-10-36c0434d3d06>:19: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['tokenized_snippet'].iloc[start_index:end_index] = chunk.apply(custom_tokenizer)
# <ipython-input-10-36c0434d3d06>:19: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['tokenized_snippet'].iloc[start_index:end_index] = chunk.apply(custom_tokenizer)
# <ipython-input-10-36c0434d3d06>:19: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['tokenized_snippet'].iloc[start_index:end_index] = chunk.apply(custom_tokenizer)
# <ipython-input-10-36c0434d3d06>:19: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['tokenized_snippet'].iloc[start_index:end_index] = chunk.apply(custom_tokenizer)
# <ipython-input-10-36c0434d3d06>:19: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['tokenized_snippet'].iloc[start_index:end_index] = chunk.apply(custom_tokenizer)
# <ipython-input-10-36c0434d3d06>:19: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['tokenized_snippet'].iloc[start_index:end_index] = chunk.apply(custom_tokenizer)
# <ipython-input-10-36c0434d3d06>:19: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['tokenized_snippet'].iloc[start_index:end_index] = chunk.apply(custom_tokenizer)
# <ipython-input-10-36c0434d3d06>:19: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['tokenized_snippet'].iloc[start_index:end_index] = chunk.apply(custom_tokenizer)
# <ipython-input-10-36c0434d3d06>:19: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['tokenized_snippet'].iloc[start_index:end_index] = chunk.apply(custom_tokenizer)
# <ipython-input-10-36c0434d3d06>:19: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['tokenized_snippet'].iloc[start_index:end_index] = chunk.apply(custom_tokenizer)
# <ipython-input-10-36c0434d3d06>:19: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['tokenized_snippet'].iloc[start_index:end_index] = chunk.apply(custom_tokenizer)
# <ipython-input-10-36c0434d3d06>:19: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['tokenized_snippet'].iloc[start_index:end_index] = chunk.apply(custom_tokenizer)
# <ipython-input-10-36c0434d3d06>:19: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['tokenized_snippet'].iloc[start_index:end_index] = chunk.apply(custom_tokenizer)
# <ipython-input-10-36c0434d3d06>:19: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['tokenized_snippet'].iloc[start_index:end_index] = chunk.apply(custom_tokenizer)
# <ipython-input-10-36c0434d3d06>:19: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['tokenized_snippet'].iloc[start_index:end_index] = chunk.apply(custom_tokenizer)
# <ipython-input-10-36c0434d3d06>:19: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['tokenized_snippet'].iloc[start_index:end_index] = chunk.apply(custom_tokenizer)
# <ipython-input-10-36c0434d3d06>:19: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['tokenized_snippet'].iloc[start_index:end_index] = chunk.apply(custom_tokenizer)
# <ipython-input-10-36c0434d3d06>:19: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['tokenized_snippet'].iloc[start_index:end_index] = chunk.apply(custom_tokenizer)
# <ipython-input-10-36c0434d3d06>:19: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['tokenized_snippet'].iloc[start_index:end_index] = chunk.apply(custom_tokenizer)
# <ipython-input-10-36c0434d3d06>:19: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['tokenized_snippet'].iloc[start_index:end_index] = chunk.apply(custom_tokenizer)
# <ipython-input-10-36c0434d3d06>:19: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['tokenized_snippet'].iloc[start_index:end_index] = chunk.apply(custom_tokenizer)
# <ipython-input-10-36c0434d3d06>:19: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['tokenized_snippet'].iloc[start_index:end_index] = chunk.apply(custom_tokenizer)
# <ipython-input-10-36c0434d3d06>:19: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['tokenized_snippet'].iloc[start_index:end_index] = chunk.apply(custom_tokenizer)
# <ipython-input-10-36c0434d3d06>:19: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['tokenized_snippet'].iloc[start_index:end_index] = chunk.apply(custom_tokenizer)
# <ipython-input-10-36c0434d3d06>:19: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['tokenized_snippet'].iloc[start_index:end_index] = chunk.apply(custom_tokenizer)
# <ipython-input-10-36c0434d3d06>:19: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['tokenized_snippet'].iloc[start_index:end_index] = chunk.apply(custom_tokenizer)
# <ipython-input-10-36c0434d3d06>:19: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['tokenized_snippet'].iloc[start_index:end_index] = chunk.apply(custom_tokenizer)
# <ipython-input-10-36c0434d3d06>:19: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['tokenized_snippet'].iloc[start_index:end_index] = chunk.apply(custom_tokenizer)
# <ipython-input-10-36c0434d3d06>:19: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['tokenized_snippet'].iloc[start_index:end_index] = chunk.apply(custom_tokenizer)
# <ipython-input-10-36c0434d3d06>:19: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['tokenized_snippet'].iloc[start_index:end_index] = chunk.apply(custom_tokenizer)
# <ipython-input-10-36c0434d3d06>:19: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['tokenized_snippet'].iloc[start_index:end_index] = chunk.apply(custom_tokenizer)
# <ipython-input-10-36c0434d3d06>:19: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['tokenized_snippet'].iloc[start_index:end_index] = chunk.apply(custom_tokenizer)
# <ipython-input-10-36c0434d3d06>:19: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['tokenized_snippet'].iloc[start_index:end_index] = chunk.apply(custom_tokenizer)
# <ipython-input-10-36c0434d3d06>:19: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['tokenized_snippet'].iloc[start_index:end_index] = chunk.apply(custom_tokenizer)
# <ipython-input-10-36c0434d3d06>:19: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['tokenized_snippet'].iloc[start_index:end_index] = chunk.apply(custom_tokenizer)
# <ipython-input-10-36c0434d3d06>:19: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['tokenized_snippet'].iloc[start_index:end_index] = chunk.apply(custom_tokenizer)
# <ipython-input-10-36c0434d3d06>:19: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['tokenized_snippet'].iloc[start_index:end_index] = chunk.apply(custom_tokenizer)
# <ipython-input-10-36c0434d3d06>:19: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# ...
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['tokenized_snippet'].iloc[start_index:end_index] = chunk.apply(custom_tokenizer)
# <ipython-input-10-36c0434d3d06>:19: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['tokenized_snippet'].iloc[start_index:end_index] = chunk.apply(custom_tokenizer)
# <ipython-input-10-36c0434d3d06>:19: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['tokenized_snippet'].iloc[start_index:end_index] = chunk.apply(custom_tokenizer)
# <ipython-input-10-36c0434d3d06>:19: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['tokenized_snippet'].iloc[start_index:end_index] = chunk.apply(custom_tokenizer)
# <ipython-input-10-36c0434d3d06>:19: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['tokenized_snippet'].iloc[start_index:end_index] = chunk.apply(custom_tokenizer)
# <ipython-input-10-36c0434d3d06>:19: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['tokenized_snippet'].iloc[start_index:end_index] = chunk.apply(custom_tokenizer)
# <ipython-input-10-36c0434d3d06>:19: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['tokenized_snippet'].iloc[start_index:end_index] = chunk.apply(custom_tokenizer)
# <ipython-input-10-36c0434d3d06>:19: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['tokenized_snippet'].iloc[start_index:end_index] = chunk.apply(custom_tokenizer)
# <ipython-input-10-36c0434d3d06>:19: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['tokenized_snippet'].iloc[start_index:end_index] = chunk.apply(custom_tokenizer)
# <ipython-input-10-36c0434d3d06>:19: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['tokenized_snippet'].iloc[start_index:end_index] = chunk.apply(custom_tokenizer)
# <ipython-input-10-36c0434d3d06>:19: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['tokenized_snippet'].iloc[start_index:end_index] = chunk.apply(custom_tokenizer)
# <ipython-input-10-36c0434d3d06>:19: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['tokenized_snippet'].iloc[start_index:end_index] = chunk.apply(custom_tokenizer)
# <ipython-input-10-36c0434d3d06>:19: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['tokenized_snippet'].iloc[start_index:end_index] = chunk.apply(custom_tokenizer)
# <ipython-input-10-36c0434d3d06>:19: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['tokenized_snippet'].iloc[start_index:end_index] = chunk.apply(custom_tokenizer)
# <ipython-input-10-36c0434d3d06>:19: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['tokenized_snippet'].iloc[start_index:end_index] = chunk.apply(custom_tokenizer)
# <ipython-input-10-36c0434d3d06>:19: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['tokenized_snippet'].iloc[start_index:end_index] = chunk.apply(custom_tokenizer)
#                name of the function  \
# 0      InteractiveDecorator._logdef
# 1              Writer._write_frames
# 2  WinkApiInterface.update_firmware
# 3                            select
# 4                Optimizer._rmsprop
#
#                                          description  \
# 0  Logs the definition of the object that was jus...
# 1                  Write metadata to a file handle .
# 2  Make a call to the update_firmware endpoint . ...
# 3                                    datbase dialect
# 4      Uses RMSProp to compute step from gradients .
#
#                                      snippet of code  \
# 0  def _logdef ( self , n , o , otype ) : import ...
# 1  def _write_frames ( self , handle ) : assert h...
# 2  def update_firmware ( self , device , id_overr...
# 3  def select ( table , key = 'default' ) : datab...
# 4  def _rmsprop ( self , grads , cache = None , d...
#
#                                    tokenized_snippet
# 0  [(KEYWORD, def), (ID, _logdef), (PAREN, (), (I...
# 1  [(KEYWORD, def), (ID, _write_frames), (PAREN, ...
# 2  [(KEYWORD, def), (ID, update_firmware), (PAREN...
# 3  [(KEYWORD, def), (ID, select), (PAREN, (), (ID...
# 4  [(KEYWORD, def), (ID, _rmsprop), (PAREN, (), (...

# %%
df['tokenized_snippet'].iloc[0]
# Out:
# [('KEYWORD', 'def'),
#  ('ID', '_logdef'),
#  ('PAREN', '('),
#  ('ID', 'self'),
#  ('ID', 'n'),
#  ('ID', 'o'),
#  ('ID', 'otype'),
#  ('PAREN', ')'),
#  ('ID', 'import'),
#  ('ID', 're'),
#  ('ID', 'try'),
#  ('ID', 'The'),
#  ('ID', 'latest'),
#  ('ID', 'input'),
#  ('ID', 'cell'),
#  ('ID', 'will'),
#  ('ID', 'be'),
#  ('ID', 'the'),
#  ('ID', 'one'),
#  ('ID', 'that'),
#  ('ID', 'this'),
#  ('ID', 'got'),
#  ('ID', 'executed'),
#  ('ID', 'from'),
#  ('ID', 'TODO'),
#  ('ID', 'actually'),
#  ('KEYWORD', 'if'),
#  ('ID', 'acorn'),
#  ('ID', 'got'),
#  ('ID', 'imported'),
#  ('ID', 'after'),
#  ('ID', 'the'),
#  ('ID', 'fact'),
#  ('ID', 'then'),
#  ('ID', 'the'),
#  ('ID', 'import'),
#  ('ID', 'would'),
#  ('ID', 'have'),
#  ('ID', 'caused'),
#  ('ID', 'all'),
#  ('ID', 'the'),
#  ('ID', 'undecorated'),
#  ('ID', 'functions'),
#  ('ID', 'to'),
#  ('ID', 'be'),
#  ('ID', 'decorated'),
#  ('ID', 'as'),
#  ('ID', 'soon'),
#  ('ID', 'as'),
#  ('ID', 'acorn'),
#  ('ID', 'imported'),
#  ('ID', 'I'),
#  ('ID', 'suppose'),
#  ('ID', 'we'),
#  ('ID', 'just'),
#  ('ID', 'won'),
#  ('ID', 't'),
#  ('ID', 'have'),
#  ('ID', 'any'),
#  ('ID', 'code'),
#  ('KEYWORD', 'for'),
#  ('ID', 'that'),
#  ('ID', 'case'),
#  ('KEYWORD', 'if'),
#  ('ID', 'otype'),
#  ('ASSIGN', '='),
#  ('ASSIGN', '='),
#  ('ID', 'classes'),
#  ('ID', 'cellno'),
#  ('ASSIGN', '='),
#  ('ID', 'max'),
#  ('PAREN', '('),
#  ('PAREN', '['),
#  ('ID', 'int'),
#  ('PAREN', '('),
#  ('ID', 'k'),
#  ('PAREN', '['),
#  ('NUMBER', '2'),
#  ('PAREN', ']'),
#  ('PAREN', ')'),
#  ('KEYWORD', 'for'),
#  ('ID', 'k'),
#  ('ID', 'in'),
#  ('ID', 'self'),
#  ('ID', 'shell'),
#  ('ID', 'user_ns'),
#  ('ID', 'keys'),
#  ('PAREN', '('),
#  ('PAREN', ')'),
#  ('KEYWORD', 'if'),
#  ('ID', 're'),
#  ('ID', 'match'),
#  ('PAREN', '('),
#  ('ID', '_i'),
#  ('ID', 'd'),
#  ('OP', '+'),
#  ('ID', 'k'),
#  ('PAREN', ')'),
#  ('PAREN', ']'),
#  ('PAREN', ')'),
#  ('ID', 'elif'),
#  ('ID', 'otype'),
#  ('ASSIGN', '='),
#  ('ASSIGN', '='),
#  ('ID', 'functions'),
#  ('ID', 'cellno'),
#  ('ASSIGN', '='),
#  ('ID', 'int'),
#  ('PAREN', '('),
#  ('ID', 'o'),
#  ('ID', '__code__'),
#  ('ID', 'co_filename'),
#  ('ID', 'strip'),
#  ('PAREN', '('),
#  ('PAREN', ')'),
#  ('ID', 'split'),
#  ('PAREN', '('),
#  ('OP', '-'),
#  ('PAREN', ')'),
#  ('PAREN', '['),
#  ('NUMBER', '2'),
#  ('PAREN', ']'),
#  ('PAREN', ')'),
#  ('ID', 'except'),
#  ('ID', 'This'),
#  ('ID', 'must'),
#  ('ID', 'not'),
#  ('ID', 'have'),
#  ('ID', 'been'),
#  ('ID', 'an'),
#  ('ID', 'ipython'),
#  ('ID', 'notebook'),
#  ('ID', 'declaration'),
#  ('ID', 'so'),
#  ('ID', 'we'),
#  ('ID', 'don'),
#  ('ID', 't'),
#  ('ID', 'store'),
#  ('ID', 'the'),
#  ('ID', 'code'),
#  ('ID', 'cellno'),
#  ('ASSIGN', '='),
#  ('ID', 'None'),
#  ('ID', 'pass'),
#  ('ID', 'code'),
#  ('ASSIGN', '='),
#  ('KEYWORD', 'if'),
#  ('ID', 'cellno'),
#  ('ID', 'is'),
#  ('ID', 'not'),
#  ('ID', 'None'),
#  ('ID', 'cellstr'),
#  ('ASSIGN', '='),
#  ('ID', '_i'),
#  ('PAREN', '{'),
#  ('NUMBER', '0'),
#  ('ID', 'd'),
#  ('PAREN', '}'),
#  ('ID', 'format'),
#  ('PAREN', '('),
#  ('ID', 'cellno'),
#  ('PAREN', ')'),
#  ('KEYWORD', 'if'),
#  ('ID', 'cellstr'),
#  ('ID', 'in'),
#  ('ID', 'self'),
#  ('ID', 'shell'),
#  ('ID', 'user_ns'),
#  ('ID', 'cellcode'),
#  ('ASSIGN', '='),
#  ('ID', 'self'),
#  ('ID', 'shell'),
#  ('ID', 'user_ns'),
#  ('PAREN', '['),
#  ('ID', 'cellstr'),
#  ('PAREN', ']'),
#  ('ID', 'import'),
#  ('ID', 'ast'),
#  ('ID', 'astm'),
#  ('ASSIGN', '='),
#  ('ID', 'ast'),
#  ('ID', 'parse'),
#  ('PAREN', '('),
#  ('ID', 'cellcode'),
#  ('PAREN', ')'),
#  ('ID', 'ab'),
#  ('ASSIGN', '='),
#  ('ID', 'astm'),
#  ('ID', 'body'),
#  ('ID', 'parts'),
#  ('ASSIGN', '='),
#  ('PAREN', '{'),
#  ('ID', 'ab'),
#  ('PAREN', '['),
#  ('ID', 'i'),
#  ('PAREN', ']'),
#  ('ID', 'name'),
#  ('PAREN', '('),
#  ('ID', 'ab'),
#  ('PAREN', '['),
#  ('ID', 'i'),
#  ('PAREN', ']'),
#  ('ID', 'lineno'),
#  ('ID', 'None'),
#  ('KEYWORD', 'if'),
#  ('ID', 'i'),
#  ('OP', '+'),
#  ('NUMBER', '1'),
#  ('ASSIGN', '='),
#  ('ID', 'len'),
#  ('PAREN', '('),
#  ('ID', 'ab'),
#  ('PAREN', ')'),
#  ('KEYWORD', 'else'),
#  ('ID', 'ab'),
#  ('PAREN', '['),
#  ('ID', 'i'),
#  ('OP', '+'),
#  ('NUMBER', '1'),
#  ('PAREN', ']'),
#  ('ID', 'lineno'),
#  ('PAREN', ')'),
#  ('KEYWORD', 'for'),
#  ('ID', 'i'),
#  ('ID', 'd'),
#  ('ID', 'in'),
#  ('ID', 'enumerate'),
#  ('PAREN', '('),
#  ('ID', 'ab'),
#  ('PAREN', ')'),
#  ('PAREN', '}'),
#  ('KEYWORD', 'if'),
#  ('ID', 'n'),
#  ('ID', 'in'),
#  ('ID', 'parts'),
#  ('ID', 'celllines'),
#  ('ASSIGN', '='),
#  ('ID', 'cellcode'),
#  ('ID', 'split'),
#  ('PAREN', '('),
#  ('ID', 'n'),
#  ('PAREN', ')'),
#  ('ID', 'start'),
#  ('ID', 'end'),
#  ('ASSIGN', '='),
#  ('ID', 'parts'),
#  ('PAREN', '['),
#  ('ID', 'n'),
#  ('PAREN', ']'),
#  ('KEYWORD', 'if'),
#  ('ID', 'end'),
#  ('ID', 'is'),
#  ('ID', 'not'),
#  ('ID', 'None'),
#  ('ID', 'code'),
#  ('ASSIGN', '='),
#  ('ID', 'celllines'),
#  ('PAREN', '['),
#  ('ID', 'start'),
#  ('OP', '-'),
#  ('NUMBER', '1'),
#  ('ID', 'end'),
#  ('OP', '-'),
#  ('NUMBER', '1'),
#  ('PAREN', ']'),
#  ('KEYWORD', 'else'),
#  ('ID', 'code'),
#  ('ASSIGN', '='),
#  ('ID', 'celllines'),
#  ('PAREN', '['),
#  ('ID', 'start'),
#  ('OP', '-'),
#  ('NUMBER', '1'),
#  ('PAREN', ']'),
#  ('ID', 'Now'),
#  ('ID', 'we'),
#  ('ID', 'actually'),
#  ('ID', 'create'),
#  ('ID', 'the'),
#  ('ID', 'entry'),
#  ('ID', 'Since'),
#  ('ID', 'the'),
#  ('ID', 'execution'),
#  ('KEYWORD', 'for'),
#  ('ID', 'function'),
#  ('ID', 'definitions'),
#  ('ID', 'is'),
#  ('ID', 'almost'),
#  ('ID', 'instantaneous'),
#  ('ID', 'we'),
#  ('ID', 'just'),
#  ('ID', 'log'),
#  ('ID', 'the'),
#  ('ID', 'pre'),
#  ('ID', 'and'),
#  ('ID', 'post'),
#  ('ID', 'events'),
#  ('ID', 'at'),
#  ('ID', 'the'),
#  ('ID', 'same'),
#  ('ID', 'time'),
#  ('ID', 'from'),
#  ('ID', 'time'),
#  ('ID', 'import'),
#  ('ID', 'time'),
#  ('ID', 'from'),
#  ('ID', 'acorn'),
#  ('ID', 'logging'),
#  ('ID', 'database'),
#  ('ID', 'import'),
#  ('ID', 'record'),
#  ('ID', 'entry'),
#  ('ASSIGN', '='),
#  ('PAREN', '{'),
#  ('ID', 'm'),
#  ('KEYWORD', 'def'),
#  ('ID', 'a'),
#  ('ID', 'None'),
#  ('ID', 's'),
#  ('ID', 'time'),
#  ('PAREN', '('),
#  ('PAREN', ')'),
#  ('ID', 'r'),
#  ('ID', 'None'),
#  ('ID', 'c'),
#  ('ID', 'code'),
#  ('PAREN', '}'),
#  ('ID', 'from'),
#  ('ID', 'acorn'),
#  ('ID', 'import'),
#  ('ID', 'msg'),
#  ('ID', 'record'),
#  ('PAREN', '('),
#  ('ID', '__main__'),
#  ('PAREN', '{'),
#  ('PAREN', '}'),
#  ('ID', 'format'),
#  ('PAREN', '('),
#  ('ID', 'n'),
#  ('PAREN', ')'),
#  ('ID', 'entry'),
#  ('ID', 'diff'),
#  ('ASSIGN', '='),
#  ('ID', 'True'),
#  ('PAREN', ')'),
#  ('ID', 'msg'),
#  ('ID', 'info'),
#  ('PAREN', '('),
#  ('ID', 'entry'),
#  ('NUMBER', '1'),
#  ('PAREN', ')'),
#  ('NEWLINE', '\n'),
#  ('NUMBER', '0')]
